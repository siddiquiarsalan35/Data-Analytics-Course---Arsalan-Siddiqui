# %% [markdown]
# # Session 3

# %%
a = 12
b = 11
c = a + b

print (c)
# Out:
# 23

# %%
x = "Arsalan"
y = "26"
z = x + y

print (z)
# Out:
# Arsalan26

# %%
Age = 24
Age = Age + 1

print (Age)
# Out:
# 25

# %%
## List

salaries = ["20k", "28k", "45k", "90k", "100k", "46k", "50k", "55k", "62k"]

# %%
salaries
# Out:
# ['20k', '28k', '45k', '90k', '100k', '46k', '50k', '55k', '62k']

# %%
len(salaries)
# Out:
# 9

# %% [markdown]
# ## Indexing

# %%
# Indexing

print (salaries [5],salaries [7])
# Out:
# 46k 55k

# %%
salaries [-1
# Out:
# '62k'

# %%
salaries [-4]
# Out:
# '46k'

# %%
bio = ['Arsalan', 24, salaries, 24.6]
bio
# Out:
# ['Arsalan',
#  24,
#  ['20k', '28k', '45k', '90k', '100k', '46k', '50k', '55k', '62k'],
#  24.6]

# %%
len(bio)
# Out:
# 4

# %%
bio [2][3]
# Out:
# '90k'

# %% [markdown]
# # Slicing

# %%
salaries
# Out:
# ['20k', '28k', '45k', '90k', '100k', '46k', '50k', '55k', '62k']

# %%
#positive index
salaries [2:5]
# Out:
# ['45k', '90k', '100k']

# %%
#negative index
salaries [-6:-2]
# Out:
# ['90k', '100k', '46k', '50k']

# %%
salaries
# Out:
# ['20k', '28k', '45k', '90k', '100k', '46k', '50k', '55k', '62k']

# %%
salaries [2:]
# Out:
# ['45k', '90k', '100k', '46k', '50k', '55k', '62k']

# %%
salaries
# Out:
# ['20k', '28k', '45k', '90k', '100k', '46k', '50k', '55k', '62k']

# %%
salaries [-3:]
# Out:
# ['50k', '55k', '62k']

# %%
#stepping

salaries
# Out:
# ['20k', '28k', '45k', '90k', '100k', '46k', '50k', '55k', '62k']

# %%
salaries [2:7]
# Out:
# ['45k', '90k', '100k', '46k', '50k']

# %%
salaries [2:7:2]
# Out:
# ['45k', '100k', '50k']

# %%
type (salaries)
# Out:
# list

# %%
salaries.index('90k')
# Out:
# 3
