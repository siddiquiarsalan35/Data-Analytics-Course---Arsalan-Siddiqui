# %% [markdown]
# ## Tuple
# ### In pyhton, a tuple is used to store multiple variables in a single variable, just like a list. However, tuples are immutable

# %%
bio = ("Arsalan", 25, "Coffee", "arsalan@gmail.com")
bio
# Out:
# ('Arsalan', 25, 'Coffee', 'arsalan@gmail.com')

# %%
bio [3]
# Out:
# 'arsalan@gmail.com'

# %%
dir (())
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
bio = ("Arsalan", 25, "Coffee", "arsalan@gmail.com", 25)
bio
# Out:
# ('Arsalan', 25, 'Coffee', 'arsalan@gmail.com', 25)

# %%
bio.count(25)
# Out:
# 2

# %%
bio
# Out:
# ('Arsalan', 25, 'Coffee', 'arsalan@gmail.com', 25)

# %%
bio.index("Coffee")
# Out:
# 2

# %%
bio_list = list(bio)

bio_list
# Out:
# ['Arsalan', 25, 'Coffee', 'arsalan@gmail.com', 25]

# %%
bio
# Out:
# ('Arsalan', 25, 'Coffee', 'arsalan@gmail.com', 25)

# %%
type(bio)
# Out:
# tuple

# %%
type(bio_list)
# Out:
# list

# %%
tuple(bio_list)
# Out:
# ('Arsalan', 25, 'Coffee', 'arsalan@gmail.com', 25)

# %%
type(bio_list)
# Out:
# list

# %% [markdown]
# ## Unpacking

# %%
bio
# Out:
# ('Arsalan', 25, 'Coffee', 'arsalan@gmail.com', 25)

# %%
len (bio)
# Out:
# 5

# %% [markdown]
# ## Dictionary
# In python, a dictionary is mutable collection of key calue pairs.

# %%
my_dict = {
    "name":"Arsalan",
    "age": 25,
    "city": "Karachi"
}

# %%
my_dict
# Out:
# {'name': 'Arsalan', 'age': 25, 'city': 'Karachi'}

# %%
my_dict["name"]
# Out:
# 'Arsalan'

# %%
my_dict["age"]
# Out:
# 25

# %%
my_dict.get("name")
# Out:
# 'Arsalan'

# %%
dir ({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
my_dict.values()
# Out:
# dict_values(['Arsalan', 25, 'Karachi'])

# %%
my_dict.items()
# Out:
# dict_items([('name', 'Arsalan'), ('age', 25), ('city', 'Karachi')])

# %%
my_dict
# Out:
# {'name': 'Arsalan', 'age': 25, 'city': 'Karachi'}

# %%
my_dict.update({"email":"arsalan@gmail.com"})

# %%
my_dict
# Out:
# {'name': 'Arsalan', 'age': 25, 'city': 'Karachi', 'email': 'arsalan@gmail.com'}

# %%
my_dict.update({'age':24})

# %%
my_dict
# Out:
# {'name': 'Arsalan', 'age': 24, 'city': 'Karachi', 'email': 'arsalan@gmail.com'}

# %%
my_dict['city']
# Out:
# 'Karachi'

# %%
my_dict['city'] = 'Multan'

# %%
my_dict
# Out:
# {'name': 'Arsalan', 'age': 24, 'city': 'Multan', 'email': 'arsalan@gmail.com'}

# %%
my_dict['Food'] = 'Pizza'

# %%
my_dict
# Out:
# {'name': 'Arsalan',
#  'age': 24,
#  'city': 'Multan',
#  'email': 'arsalan@gmail.com',
#  'Food': 'Pizza'}

# %%
my_dict.popitem()
# Out:
# ('Food', 'Pizza')

# %%
my_dict
# Out:
# {'name': 'Arsalan', 'age': 24, 'city': 'Multan', 'email': 'arsalan@gmail.com'}

# %% [markdown]
# #### Nested Dictionary

# %%
employee = {
    101 : {'name': 'Khan', 'age': 22, 'salary': 220000}
}

# %% [markdown]
# ## Set

# %% [markdown]
# ## Practice Question

# %%
#Question 01: Create a tuple of 5 fruits and print the third fruit.

fruits = ("apple", "mango", "banana", "kiwi", "cherry")

fruits

fruits[3]
# Out:
# 'kiwi'

# %%
#Question 02: Write a program to count how many times '2' apears in tuple.

number = (1, 2, 3, 2, 4, 2, 5)

number.count (2)
# Out:
# 3

# %%
#Question 03: Create a tuple of names and unpack them in to variable

students = ("Arsalan", "Ali", "Hamza", "Areeb", "Kashan")
students

student1, student2, student3, student4, student5 = students

student1
# Out:
# 'Arsalan'

# %%
student2
# Out:
# 'Ali'

# %%
student3
# Out:
# 'Hamza'

# %%
#Question 04: find the index of "python" in this tuple

languages = ("Java", "C++", "Python", "SQL")

languages.index ("Python")
# Out:
# 2

# %%
#Question 05: write a program to slice the tuple and print only the middle elements

numbers = ( 10, 20, 30, 40, 50, 60, 70)

numbers [2:5]
# Out:
# (30, 40, 50)

# %% [markdown]
# #### Dictionary

# %%
#Question 01: Create a dictionary of a student with keys: name, age, marks, city

stud_dict = {
    "name":"Huzaifa",
    "age": 22,
    "marks": 72,
    "city": "Karachi"
}

# %%
stud_dict
# Out:
# {'name': 'Huzaifa', 'age': 22, 'marks': 72, 'city': 'Karachi'}

# %%
#Question 02: Print only the keys of this dictionary

num_dict = {
    "A":10,
    "B":20,
    "C":30
}

# %%
num_dict.keys()
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
#Question 03: Update the age of student dictionary

stud_dict.update({'age': 23})
stud_dict
# Out:
# {'name': 'Huzaifa', 'age': 23, 'marks': 72, 'city': 'Karachi'}

# %%
#Question 05: Create a dictionary of 3 products with price and print the price of one product

prod_dict = {
    "Book":"Price: Rs. 250",
    "Pen":"Price: Rs. 25",
    "Pencil Box": "Price: Rs. 320"
}

prod_dict ['Pen']
# Out:
# 'Price: Rs. 25'
